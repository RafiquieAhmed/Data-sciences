# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
labels=['a','b','c']
mylist=[10,20,30]
arr=np.array([100,200,310])
d={'x':10,'y':20,'z':30}

# %%
pd.Series(mylist,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr,index=d)
# Out:
# x    100
# y    200
# z    310
# dtype: int64

# %%
pd.Series(d)
# Out:
# x    10
# y    20
# z    30
# dtype: int64
